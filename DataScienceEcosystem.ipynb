# %% [markdown]
# <a href="https://colab.research.google.com/github/EwertonOliveira01/TestRepo/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Neste notebook, as Ferramentas e Ecossistema de Ciência de Dados são resumidos.

# %% [markdown]
# **Objetivos:**
#
# * Criar tabelas em Markdown
# * Converter minutos em horas usando Python
# * Listar bibliotecas comuns de Ciência de Dados

# %% [markdown]
# ### Algumas das linguagens populares que os Cientistas de Dados usam são:
#
# 1. Python
# 2. R
# 3. Julia
# 4. SQL

# %% [markdown]
# #### Algumas das bibliotecas comumente usadas por Cientistas de Dados incluem:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn

# %% [markdown]
# | Ferramentas de Ciência de Dados |
# | :--- |
# | Jupyter |
# | RStudio |
# | VS Code |

# %% [markdown]
# ### Abaixo estão alguns exemplos de avaliação de expressões aritméticas em Python

# %%
# Esta é uma expressão aritmética simples para multiplicar e depois adicionar inteiros

(3*4)+5
# Out:
# 17

# %%
# Isso converterá 200 minutos em horas dividindo por 60

200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Ewerton
